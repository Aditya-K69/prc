# %%
"""
Data Visualization I
1. Use the inbuilt dataset 'titanic'. The dataset contains 891 rows and contains information
about the passengers who boarded the unfortunate Titanic ship. Use the Seaborn library to
see if we can find any patterns in the data.
2. Write a code to check how the price of the ticket (column name: 'fare') for each passenger
is distributed by plotting a histogram
"""
# Out:
# "\nData Visualization I\n1. Use the inbuilt dataset 'titanic'. The dataset contains 891 rows and contains information\nabout the passengers who boarded the unfortunate Titanic ship. Use the Seaborn library to\nsee if we can find any patterns in the data.\n2. Write a code to check how the price of the ticket (column name: 'fare') for each passenger\nis distributed by plotting a histogram\n"

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('Titanic-Dataset.xls')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.countplot(x="Survived", data=df)
# Out:
# <AxesSubplot: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="Sex", hue="Survived", data=df)
# Out:
# <AxesSubplot: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x="Pclass", hue="Survived", data=df)
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='count'>

# %%
sns.histplot(df['Age'].dropna(), kde=True)
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(df['Fare'], bins=30, kde=True)
plt.title("Fare Distribution")
plt.show()

# %%
#Part 2: Histogram of Fares
sns.histplot(df['Fare'], bins=40, kde=True)
# Out:
# <AxesSubplot: xlabel='Fare', ylabel='Count'>

# %%
#bins = intervals used to group continuous data in a histogram
#kde = Kernel Density Estimate = smmooth estimate of prob density func of data

# %%
#PRACTICAL 9!!!!!!!!!!!!!!!!!!!!

# %%
"""Data Visualization II
1. Use the inbuilt dataset 'titanic' as used in the above problem. Plot a box plot for distribution
of age with respect to each gender along with the information about whether they survived
or not. (Column names : 'sex' and 'age')
2. Write observations on the inference from the above statistics."""
# Out:
# "Data Visualization II\n1. Use the inbuilt dataset 'titanic' as used in the above problem. Plot a box plot for distribution\nof age with respect to each gender along with the information about whether they survived\nor not. (Column names : 'sex' and 'age')\n2. Write observations on the inference from the above statistics."

# %%
df.dropna
sns.boxplot(x="Sex", y="Age", hue="Survived", data = df)
# Out:
# <AxesSubplot: xlabel='Sex', ylabel='Age'>

# %%
#middle line - median
#box = interquartile range
#the black line above and below box = range
#outliers = dots

#For each gender, 50% of the population lie in the box area. 
#observed that lower aged men survived more than higher aged
#females had higher survival rate
#children had higher survival rate
#survived people tend to be younger
#some passengers are very old.
#Box plots are used to visualize distribution, median, spread, 
#and outliers of numerical data across categories.


#Outliers:
# - detect using boxplot method - dots outside those black lines
# - IQR method:
#     IQR = Q3 - Q1
#     lower bound = Q1 - 1.5 * IQR
#     upper bound = Q3 + 1.5 * IQR

# handle:
#     - delete them (remove)
#     - limit them (if you dont want to lose data)
#     - replace with median
#     - log transformations
